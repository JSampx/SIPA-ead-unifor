# %%
import pandas as pd
import seaborn as sb
sb.set_style("whitegrid")

# %%
sb.set_theme(style="whitegrid", palette="pastel")

# %%
path = "data/olist/"  # caminho raiz até os arquivos *.csv
items = pd.read_csv(path + "olist_order_items_dataset.csv")

# %%
items.shape
# Out:
# (112650, 7)

# %%
items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
agrupado = items['order_id'].describe()
agrupado
# Out:
# count                               112650
# unique                               98666
# top       8272b63d03f5f79c56e9e4120aec44ef
# freq                                    21
# Name: order_id, dtype: object

# %%
agrupado = items['product_id'].describe()
agrupado
# Out:
# count                               112650
# unique                               32951
# top       aca2eb7d00ea1a7b8ebd4e68314663af
# freq                                   527
# Name: product_id, dtype: object

# %%
prod = items[(items['product_id'] == "aca2eb7d00ea1a7b8ebd4e68314663af")]
prod
# Out:
#                                 order_id  order_item_id  \
# 258     00a870c6c06346e85335524935c600c0              1
# 619     016ff85737c2072ab00a705cd8f87799              1
# 643     017b1d6881222283afdc50baf3dcb0d5              1
# 1172    02b939dcd55f2b17680e10690deb08b5              1
# 1173    02b939dcd55f2b17680e10690deb08b5              2
# ...                                  ...            ...
# 112022  fe7d49cdcf690228d8d476caf24ef2d5              1
# 112027  fe802824215762b3ea5f49760eac0bd4              1
# 112028  fe802824215762b3ea5f49760eac0bd4              2
# 112212  feec317d7127a4dc69cfb507f08c8759              1
# 112427  ff74eadad84626e98512334e5296adeb              1
#
#                               product_id                         seller_id  \
# 258     aca2eb7d00ea1a7b8ebd4e68314663af  955fee9216a65b617aa5c0531780ce60
# 619     aca2eb7d00ea1a7b8ebd4e68314663af  955fee9216a65b617aa5c0531780ce60
# ...

# %%
prod['price'].describe()
# Out:
# count    527.000000
# mean      71.364137
# std        3.670723
# min       69.900000
# 25%       69.900000
# 50%       69.900000
# 75%       69.900000
# max      109.900000
# Name: price, dtype: float64

# %%
sb.boxplot(prod['price'], orient='h').set_title("Preço")
# Out:
# Text(0.5, 1.0, 'Preço')

# %%
agrupado = items['seller_id'].describe()
agrupado
# Out:
# count                               112650
# unique                                3095
# top       6560211a19b47992c3666cc44a7e94c0
# freq                                  2033
# Name: seller_id, dtype: object

# %%
agrupado = items['seller_id'].describe()
agrupado
# Out:
# count                               112650
# unique                                3095
# top       6560211a19b47992c3666cc44a7e94c0
# freq                                  2033
# Name: seller_id, dtype: object

# %%
top_10_itens = items['order_id'].value_counts()[:10]
top_10_itens
# Out:
# order_id
# 8272b63d03f5f79c56e9e4120aec44ef    21
# 1b15974a0141d54e36626dca3fdc731a    20
# ab14fdcfbe524636d65ee38360e22ce8    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
# 73c8ab38f07dc94389065f7eba4f297a    14
# 9bdc4d4c71aa1de4606060929dee888c    14
# 37ee401157a3a0b28c9c6d0ed8c3b24b    13
# 637617b3ffe9e2f7a2411243829226d0    12
# 2c2a19b5703863c908512d135aa6accc    12
# Name: count, dtype: int64
