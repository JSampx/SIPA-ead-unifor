# %%
# Importação de bibliotecas
import pandas as pd
import statistics as st

# %%
path = "data/olist/" # caminho raiz até os arquivos *.csv
orders = pd.read_csv(path + "olist_orders_dataset.csv")
items = pd.read_csv(path + "olist_order_items_dataset.csv")
products = pd.read_csv(path + "olist_products_dataset.csv")
reviews = pd.read_csv(path + "olist_order_reviews_dataset.csv")
# customers = pd.read_csv(path + "olist_customers_dataset.csv")
# payments = pd.read_csv(path + "olist_order_payments_dataset.csv")
# sellers = pd.read_csv(path + "olist_sellers_dataset.csv")
# geo = pd.read_csv(path + "olist_geolocation_dataset.csv")
# translations = pd.read_csv(path + "product_category_name_translation.csv")

# %%
df_merged = pd.merge(orders, items, how="right" ,on="order_id")

# %%
df_merged_2 = pd.merge(df_merged, products, how="left" ,on="product_id")

# %%
df_merged_3 = pd.merge(df_merged_2, reviews, how="left" ,on="order_id")

# %%
df_merged_3.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'product_category_name',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp'],
#       dtype='object')

# %%
df_merged_3.to_csv(path + "merged/olist_merged_dataset.csv", index=False)

# %%
datasets_info = {
    "Orders": orders,
    "Items": items,
    "Products": products,
    "Reviews": reviews
}

for name, df in datasets_info.items():
    print(f"\n--- {name} | Shape: {df.shape} ---")
# Out:
# --- Orders | Shape: (99441, 8) ---
#
# --- Items | Shape: (112650, 7) ---
#
# --- Products | Shape: (32951, 9) ---
#
# --- Reviews | Shape: (99224, 7) ---

# %%
agrupado = orders.groupby("order_status").size()
agrupado
# Out:
# order_status
# approved           2
# canceled         625
# created            5
# delivered      96478
# invoiced         314
# processing       301
# shipped         1107
# unavailable      609
# dtype: int64

# %%
# items
# df[items['price'].agg()]
items.groupby('price')['price'].count()
# Out:
# price
# 0.85        3
# 1.20       20
# 2.20        1
# 2.29        1
# 2.90        1
#            ..
# 4690.00     1
# 4799.00     1
# 6499.00     1
# 6729.00     1
# 6735.00     1
# Name: price, Length: 5968, dtype: int64

# %%
items["seller_id"].nunique()
# Out:
# 3095

# %%
products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...
